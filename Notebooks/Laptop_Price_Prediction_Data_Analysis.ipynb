# %% [markdown]
# # Loading data

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("data/laptop_data.csv")

# %%
df
# Out:
#       Unnamed: 0 Company            TypeName  Inches  \
# 0              0   Apple           Ultrabook    13.3
# 1              1   Apple           Ultrabook    13.3
# 2              2      HP            Notebook    15.6
# 3              3   Apple           Ultrabook    15.4
# 4              4   Apple           Ultrabook    13.3
# ...          ...     ...                 ...     ...
# 1298        1298  Lenovo  2 in 1 Convertible    14.0
# 1299        1299  Lenovo  2 in 1 Convertible    13.3
# 1300        1300  Lenovo            Notebook    14.0
# 1301        1301      HP            Notebook    15.6
# 1302        1302    Asus            Notebook    15.6
#
#                                 ScreenResolution  \
# 0             IPS Panel Retina Display 2560x1600
# 1                                       1440x900
# 2                              Full HD 1920x1080
# 3             IPS Panel Retina Display 2880x1800
# 4             IPS Panel Retina Display 2560x1600
# ...                                          ...
# 1298   IPS Panel Full HD / Touchscreen 1920x1080
# 1299  IPS Panel Quad HD+ / Touchscreen 3200x1800
# 1300                                    1366x768
# 1301                                    1366x768
# 1302                                    1366x768
#
#                                        Cpu   Ram               Memory  \
# 0                     Intel Core i5 2.3GHz   8GB            128GB SSD
# 1                     Intel Core i5 1.8GHz   8GB  128GB Flash Storage
# 2               Intel Core i5 7200U 2.5GHz   8GB            256GB SSD
# 3                     Intel Core i7 2.7GHz  16GB            512GB SSD
# 4                     Intel Core i5 3.1GHz   8GB            256GB SSD
# ...                                    ...   ...                  ...
# 1298            Intel Core i7 6500U 2.5GHz   4GB            128GB SSD
# 1299            Intel Core i7 6500U 2.5GHz  16GB            512GB SSD
# 1300  Intel Celeron Dual Core N3050 1.6GHz   2GB   64GB Flash Storage
# 1301            Intel Core i7 6500U 2.5GHz   6GB              1TB HDD
# 1302  Intel Celeron Dual Core N3050 1.6GHz   4GB            500GB HDD
#
#                                Gpu       OpSys  Weight        Price
# 0     Intel Iris Plus Graphics 640       macOS  1.37kg   71378.6832
# 1           Intel HD Graphics 6000       macOS  1.34kg   47895.5232
# 2            Intel HD Graphics 620       No OS  1.86kg   30636.0000
# 3               AMD Radeon Pro 455       macOS  1.83kg  135195.3360
# 4     Intel Iris Plus Graphics 650       macOS  1.37kg   96095.8080
# ...                            ...         ...     ...          ...
# 1298         Intel HD Graphics 520  Windows 10   1.8kg   33992.6400
# 1299         Intel HD Graphics 520  Windows 10   1.3kg   79866.7200
# 1300             Intel HD Graphics  Windows 10   1.5kg   12201.1200
# 1301            AMD Radeon R5 M330  Windows 10  2.19kg   40705.9200
# 1302             Intel HD Graphics  Windows 10   2.2kg   19660.3200
#
# [1303 rows x 12 columns]

# %%
df.shape
# Out:
# (1303, 12)

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.isnull().sum()
# Out:
# Unnamed: 0          0
# Company             0
# TypeName            0
# Inches              0
# ScreenResolution    0
# Cpu                 0
# Ram                 0
# Memory              0
# Gpu                 0
# OpSys               0
# Weight              0
# Price               0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1303 entries, 0 to 1302
# Data columns (total 12 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Unnamed: 0        1303 non-null   int64
#  1   Company           1303 non-null   object
#  2   TypeName          1303 non-null   object
#  3   Inches            1303 non-null   float64
#  4   ScreenResolution  1303 non-null   object
#  5   Cpu               1303 non-null   object
#  6   Ram               1303 non-null   object
#  7   Memory            1303 non-null   object
#  8   Gpu               1303 non-null   object
#  9   OpSys             1303 non-null   object
#  10  Weight            1303 non-null   object
#  11  Price             1303 non-null   float64
# dtypes: float64(2), int64(1), object(9)
# memory usage: 122.3+ KB

# %%
df.sample(5)
# Out:
#      Unnamed: 0 Company            TypeName  Inches  \
# 773         773    Dell              Gaming    15.6
# 889         889  Lenovo            Notebook    17.3
# 608         608  Lenovo  2 in 1 Convertible    15.6
# 967         967      HP            Notebook    15.6
# 500         500    Asus             Netbook    11.6
#
#                               ScreenResolution  \
# 773                          Full HD 1920x1080
# 889                                   1600x900
# 608  IPS Panel Full HD / Touchscreen 1920x1080
# 967                          Full HD 1920x1080
# 500                                   1366x768
#
#                                       Cpu  Ram              Memory  \
# 773           Intel Core i7 7700HQ 2.8GHz  8GB             1TB HDD
# 889             AMD A4-Series 7210 2.2GHz  4GB           500GB HDD
# 608           Intel Core i7 7700HQ 2.8GHz  8GB           256GB SSD
# 967            Intel Core i3 7100U 2.4GHz  4GB           500GB HDD
# 500  Intel Celeron Dual Core N3350 1.1GHz  4GB  64GB Flash Storage
#
#                          Gpu         OpSys  Weight     Price
# 773  Nvidia GeForce GTX 1050    Windows 10  2.62kg  58554.72
# 889            AMD Radeon R3    Windows 10   2.8kg  20193.12
# 608    Intel HD Graphics 630    Windows 10     2kg  69210.72
# 967    Intel HD Graphics 620    Windows 10  2.04kg  36496.80
# 500    Intel HD Graphics 500  Windows 10 S   1.2kg  18115.20

# %%
##### Dataframe summary #####

# Shape of the dataset : (1303, 15)
# Dataset has no duplicate entry/ row
# None of the columns in the dataset is empty
# 0    'Unnamed: 0' ---> is not needed
# 1    'Company' ------> string containing the name of the company/ brand
# 2    'TypeName' -----> string containing the type of the laptop
# 3    'Inches' -----> float containing the screen size of the laptop in inches
# 4    'ScreenResolution' -----> string containing the details of screen resolution a the laptop
# 11   'Cpu' -----> string containing the laptop CPU details
# 5    'Ram' -----> string containing the RAM size of a laptop
# 6    'Memory' -----> string containing laptop memory details
# 7    'Gpu' -----> string containing laptop GPu details
# 8    'OpSys' -----> string containing the type of the Operating System
# 9    'Weight' -----> string containing the weight of the laptop
# 10   'Price' -----> float containing the price of the laptop --->  (ouput)

# %% [markdown]
# # Data Cleaning

# %%
##### Data Cleaning Agenda #####

# remove 0 column as it is unnecessery
# convert 'Ram' and 'weight' into int by removing 'GB' and 'kg' from the content 
# change types of columns to save memory

# %%
df.drop(columns = ['Unnamed: 0'], inplace = True)

# %%
df['Ram'] = df['Ram'].str.replace('GB', '')
df['Weight'] = df['Weight'].str.replace('kg', '')

# %%
df['Ram'] = df['Ram'].astype('int')
df['Weight'] = df['Weight'].astype('float')
df['Inches'] = df['Inches'].astype('float')
df['Price'] = df['Price'].astype('int')

# %%
df.sample(5)
# Out:
#      Company   TypeName  Inches             ScreenResolution  \
# 645   Lenovo   Notebook    14.0                     1366x768
# 375       HP   Notebook    15.6            Full HD 1920x1080
# 331  Toshiba   Notebook    15.6  IPS Panel Full HD 1920x1080
# 411   Lenovo  Ultrabook    14.0  IPS Panel Full HD 2560x1440
# 92        HP   Notebook    13.3            Full HD 1920x1080
#
#                                       Cpu  Ram              Memory  \
# 645  Intel Celeron Dual Core N3060 1.6GHz    4  32GB Flash Storage
# 375               AMD A9-Series 9420 3GHz    4           256GB SSD
# 331            Intel Core i5 7200U 2.5GHz    8           256GB SSD
# 411           Intel Core i7 7700HQ 2.8GHz    8           512GB SSD
# 92             Intel Core i7 8550U 1.8GHz   16           512GB SSD
#
#                          Gpu       OpSys  Weight   Price
# 645        Intel HD Graphics  Windows 10    1.43   14598
# 375            AMD Radeon R5  Windows 10    1.91   26053
# 331    Intel HD Graphics 620  Windows 10    2.00   50243
# 411  Nvidia GeForce GT 940MX  Windows 10    1.70  103523
# 92    Intel UHD Graphics 620  Windows 10    1.49   63776

# %% [markdown]
# # Feature Engineering

# %%
print(df.info())
print(df.sample(3))
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1303 entries, 0 to 1302
# Data columns (total 11 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Company           1303 non-null   object
#  1   TypeName          1303 non-null   object
#  2   Inches            1303 non-null   float64
#  3   ScreenResolution  1303 non-null   object
#  4   Cpu               1303 non-null   object
#  5   Ram               1303 non-null   int32
#  6   Memory            1303 non-null   object
#  7   Gpu               1303 non-null   object
#  8   OpSys             1303 non-null   object
#  9   Weight            1303 non-null   float64
#  10  Price             1303 non-null   int32
# dtypes: float64(2), int32(2), object(7)
# memory usage: 101.9+ KB
# None
#     Company     TypeName  Inches   ScreenResolution  \
# 438  Lenovo    Ultrabook    14.0          2560x1440
# 269  Lenovo     Notebook    15.6  Full HD 1920x1080
# 447    Dell  Workstation    15.6  Full HD 1920x1080
#
#                              Cpu  Ram                         Memory  \
# 438   Intel Core i7 7500U 2.7GHz   24                      512GB SSD
# 269   Intel Core i7 8550U 1.8GHz    8                      256GB SSD
# 447  Intel Xeon E3-1505M V6 3GHz    8  64GB Flash Storage +  1TB HDD
#
#                         Gpu       OpSys  Weight   Price
# 438   Intel HD Graphics 620  Windows 10    1.32  126912
# 269  Intel UHD Graphics 620  Windows 10    2.05   46886
# 447      Nvidia Quadro M620  Windows 10    2.23  106187

# %%
##### Feature Engineering Agenda #####

# %%
df['ScreenResolution'].value_counts()
# Out:
# ScreenResolution
# Full HD 1920x1080                                507
# 1366x768                                         281
# IPS Panel Full HD 1920x1080                      230
# IPS Panel Full HD / Touchscreen 1920x1080         53
# Full HD / Touchscreen 1920x1080                   47
# 1600x900                                          23
# Touchscreen 1366x768                              16
# Quad HD+ / Touchscreen 3200x1800                  15
# IPS Panel 4K Ultra HD 3840x2160                   12
# IPS Panel 4K Ultra HD / Touchscreen 3840x2160     11
# 4K Ultra HD / Touchscreen 3840x2160               10
# 4K Ultra HD 3840x2160                              7
# Touchscreen 2560x1440                              7
# IPS Panel 1366x768                                 7
# IPS Panel Quad HD+ / Touchscreen 3200x1800         6
# IPS Panel Retina Display 2560x1600                 6
# IPS Panel Retina Display 2304x1440                 6
# Touchscreen 2256x1504                              6
# IPS Panel Touchscreen 2560x1440                    5
# IPS Panel Retina Display 2880x1800                 4
# IPS Panel Touchscreen 1920x1200                    4
# 1440x900                                           4
# IPS Panel 2560x1440                                4
# IPS Panel Quad HD+ 2560x1440                       3
# Quad HD+ 3200x1800                                 3
# 1920x1080                                          3
# Touchscreen 2400x1600                              3
# 2560x1440                                          3
# IPS Panel Touchscreen 1366x768                     3
# IPS Panel Touchscreen / 4K Ultra HD 3840x2160      2
# IPS Panel Full HD 2160x1440                        2
# IPS Panel Quad HD+ 3200x1800                       2
# IPS Panel Retina Display 2736x1824                 1
# IPS Panel Full HD 1920x1200                        1
# IPS Panel Full HD 2560x1440                        1
# IPS Panel Full HD 1366x768                         1
# Touchscreen / Full HD 1920x1080                    1
# Touchscreen / Quad HD+ 3200x1800                   1
# Touchscreen / 4K Ultra HD 3840x2160                1
# IPS Panel Touchscreen 2400x1600                    1
# Name: count, dtype: int64

# %% [markdown]
# #### feature engineering -> 'Touchscreen' from 'ScreenResolution'

# %%
def is_touchscreen(feature_str):
    return 1 if 'Touchscreen' in str(feature_str) else 0

df['Touchscreen'] = df['ScreenResolution'].apply(is_touchscreen)

df.sample(5)
# Out:
#      Company            TypeName  Inches                 ScreenResolution  \
# 265     Dell  2 in 1 Convertible    15.6  Full HD / Touchscreen 1920x1080
# 424     Dell              Gaming    17.3              IPS Panel 2560x1440
# 793   Lenovo  2 in 1 Convertible    15.6  Full HD / Touchscreen 1920x1080
# 169       HP            Notebook    13.3      IPS Panel Full HD 1920x1080
# 1273      HP            Notebook    15.6                         1366x768
#
#                               Cpu  Ram                Memory  \
# 265    Intel Core i5 8250U 1.6GHz    8             256GB SSD
# 424   Intel Core i7 7820HK 2.9GHz   16  256GB SSD +  1TB HDD
# 793    Intel Core i5 7200U 2.5GHz    8             256GB SSD
# 169    Intel Core i5 8250U 1.6GHz    4             500GB HDD
# 1273   Intel Core i7 6500U 2.5GHz    6               1TB HDD
#
#                           Gpu       OpSys  Weight   Price  Touchscreen
# 265    Intel UHD Graphics 620  Windows 10    2.67   42570            1
# 424   Nvidia GeForce GTX 1070  Windows 10    4.42  149130            0
# 793        AMD Radeon R7 M460  Windows 10    2.08   51095            1
# 169    Intel UHD Graphics 620  Windows 10    1.49   40173            0
# 1273       AMD Radeon R5 M330  Windows 10    2.19   40705            0

# %%
# using lambda funtion
# df['Touchscreen'] = df['ScreenResolution'].apply(lambda x: 1 if 'Touchscreen' in x else 0)

# %%
# No. of laptops not having touch screen v/s having touch screen
df['Touchscreen'].value_counts().plot(kind = 'bar', figsize = (3,3), width = 0.3)
plt.show()

# variation in price due to touch screen
sns.barplot(x=df['Touchscreen'], y=df['Price'], width=0.2)
# Out:
# <Axes: xlabel='Touchscreen', ylabel='Price'>

# %% [markdown]
# #### feature engineering -> 'Ips' from 'ScreenResolution'

# %%
def is_ips(screen_str):
    return 1 if 'IPS' in str(screen_str) else 0 

df['Ips'] = df['ScreenResolution'].apply(is_ips)

df.sample(5)
# Out:
#     Company   TypeName  Inches                               ScreenResolution  \
# 610  Lenovo   Notebook    15.6                IPS Panel 4K Ultra HD 3840x2160
# 262      HP   Notebook    15.6                    IPS Panel Full HD 1920x1080
# 816   Razer  Ultrabook    12.5  IPS Panel 4K Ultra HD / Touchscreen 3840x2160
# 726    Dell   Notebook    15.6                              Full HD 1920x1080
# 770    Dell   Notebook    15.6                              Full HD 1920x1080
#
#                                Cpu  Ram                Memory  \
# 610  Intel Xeon E3-1535M v6 3.1GHz   32               1TB SSD
# 262     Intel Core i5 8250U 1.6GHz    4             500GB HDD
# 816     Intel Core i7 7500U 2.5GHz   16             512GB SSD
# 726     Intel Core i5 8250U 1.6GHz    8  128GB SSD +  1TB HDD
# 770     Intel Core i7 7500U 2.7GHz   16             256GB SSD
#
#                        Gpu       OpSys  Weight   Price  Touchscreen  Ips
# 610   Nvidia Quadro M2200M  Windows 10    2.50  261018            0    1
# 262  Intel HD Graphics 620  Windows 10    2.10   38468            0    1
# 816  Intel HD Graphics 620  Windows 10    1.29   95850            1    1
# 726         AMD Radeon 530  Windows 10    2.20   38308            0    0
# 770     AMD Radeon R7 M445  Windows 10    2.30   62938            0    0

# %%
#using lambda function
# df['Ips'] = df['ScreenResolution'].apply(lambda x: 1 if 'IPS' in x else 0)

# %%
# No. of laptops not having ips v/s having ips
df['Ips'].value_counts().plot(kind = 'bar', figsize = (3,3), width = 0.2)
plt.show()


# variation in price due to Ips display
sns.barplot(x = df['Ips'], y = df['Price'], width= 0.2 )
# Out:
# <Axes: xlabel='Ips', ylabel='Price'>

# %% [markdown]
# #### feature engineering -> 'x_res', 'y_res' from 'ScreenResolution'

# %%
new = df['ScreenResolution'].str.split('x', n = 1, expand = True)

# %%
df['x_res'] = new[0]
df['y_res'] = new[1]

# %%
df.head()
# Out:
#   Company   TypeName  Inches                    ScreenResolution  \
# 0   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
# 1   Apple  Ultrabook    13.3                            1440x900
# 2      HP   Notebook    15.6                   Full HD 1920x1080
# 3   Apple  Ultrabook    15.4  IPS Panel Retina Display 2880x1800
# 4   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
#
#                           Cpu  Ram               Memory  \
# 0        Intel Core i5 2.3GHz    8            128GB SSD
# 1        Intel Core i5 1.8GHz    8  128GB Flash Storage
# 2  Intel Core i5 7200U 2.5GHz    8            256GB SSD
# 3        Intel Core i7 2.7GHz   16            512GB SSD
# 4        Intel Core i5 3.1GHz    8            256GB SSD
#
#                             Gpu  OpSys  Weight   Price  Touchscreen  Ips  \
# 0  Intel Iris Plus Graphics 640  macOS    1.37   71378            0    1
# 1        Intel HD Graphics 6000  macOS    1.34   47895            0    0
# 2         Intel HD Graphics 620  No OS    1.86   30636            0    0
# 3            AMD Radeon Pro 455  macOS    1.83  135195            0    1
# 4  Intel Iris Plus Graphics 650  macOS    1.37   96095            0    1
#
#                            x_res y_res
# 0  IPS Panel Retina Display 2560  1600
# 1                           1440   900
# 2                   Full HD 1920  1080
# 3  IPS Panel Retina Display 2880  1800
# 4  IPS Panel Retina Display 2560  1600

# %%
# # Function to extract the first number
# import re


# def extract_x_res(value):
#     value = value.replace(',', '')  # Remove commas
#     numbers = re.findall(r'(\d+\.?\d+)', value)  # Find all numbers
#     return numbers[0] if numbers else None  # Return the first number

# # Apply function without lambda
# df['x_res'] = df['x_res'].apply(extract_x_res)

# df.sample(5)

# %%
df['x_res'] = df['x_res'].str.replace(',' , '').str.findall(r'(\d+\.?\d+)').apply(lambda x: x[0])

"""Code Breakdown:

1. The str.replace(',', '') function removes any commas from the values in the 'x_res' column.  
   - Example: "1,920" becomes "1920".

2. The .str.findall(r'(\d+\.?\d+)') function searches for numbers in the string. It captures both whole numbers and decimal numbers if present.  
   - Example: "1920x1080" becomes ['1920', '1080'].

3. The .apply(lambda x: x[0]) function takes the first number from the list and assigns it to the column.  
   - Example: ['1920', '1080'] → '1920'.

"""
# Out:
# <>:3: SyntaxWarning: invalid escape sequence '\d'
# <>:3: SyntaxWarning: invalid escape sequence '\d'
# C:\Users\saikat roy\AppData\Local\Temp\ipykernel_24272\4171990495.py:3: SyntaxWarning: invalid escape sequence '\d'
#   """Code Breakdown:
# 'Code Breakdown:\n\n1. The str.replace(\',\', \'\') function removes any commas from the values in the \'x_res\' column.  \n   - Example: "1,920" becomes "1920".\n\n2. The .str.findall(r\'(\\d+\\.?\\d+)\') function searches for numbers in the string. It captures both whole numbers and decimal numbers if present.  \n   - Example: "1920x1080" becomes [\'1920\', \'1080\'].\n\n3. The .apply(lambda x: x[0]) function takes the first number from the list and assigns it to the column.  \n   - Example: [\'1920\', \'1080\'] → \'1920\'.\n\n'

# %%
df.sample(10)
# Out:
#       Company            TypeName  Inches                 ScreenResolution  \
# 310    Lenovo            Notebook    13.3      IPS Panel Full HD 1920x1080
# 485    Lenovo            Notebook    14.0      IPS Panel Full HD 1920x1080
# 871    Lenovo            Notebook    15.6                Full HD 1920x1080
# 697      Asus  2 in 1 Convertible    12.5  Full HD / Touchscreen 1920x1080
# 161      Acer            Notebook    17.3      IPS Panel Full HD 1920x1080
# 1216     Acer            Notebook    17.3                         1600x900
# 648   Toshiba            Notebook    13.3                Full HD 1920x1080
# 96       Dell            Notebook    15.6                Full HD 1920x1080
# 424      Dell              Gaming    17.3              IPS Panel 2560x1440
# 673    Lenovo            Notebook    15.6                         1366x768
#
#                               Cpu  Ram                Memory  \
# 310    Intel Core i5 7200U 2.5GHz    8             256GB SSD
# 485    Intel Core i5 8250U 1.6GHz    8             256GB SSD
# 871      Intel Core i3 6006U 2GHz    4               1TB HDD
# 697   Intel Core M M3-6Y30 0.9GHz    4    64GB Flash Storage
# 161    Intel Core i5 8250U 1.6GHz    4             256GB SSD
# 1216     Intel Core i3 6006U 2GHz    4               1TB HDD
# 648    Intel Core i5 6200U 2.3GHz    8             256GB SSD
# 96     Intel Core i7 7500U 2.7GHz    8               1TB HDD
# 424   Intel Core i7 7820HK 2.9GHz   16  256GB SSD +  1TB HDD
# 673   AMD E-Series E2-9000 2.2GHz    4             128GB SSD
#
#                           Gpu       OpSys  Weight   Price  Touchscreen  Ips  \
# 310     Intel HD Graphics 620  Windows 10    1.10   53226            0    1
# 485    Intel UHD Graphics 620  Windows 10    1.75   55890            0    1
# 871        AMD Radeon R5 M430       No OS    2.20   25521            0    0
# 697     Intel HD Graphics 515   Chrome OS    1.20   35644            1    0
# 161      Nvidia GeForce MX150  Windows 10    3.00   42890            0    1
# 1216     Nvidia GeForce 940MX  Windows 10    3.30   31861            0    0
# 648     Intel HD Graphics 520  Windows 10    1.20   64628            0    0
# 96         AMD Radeon R5 M430       Linux    2.20   31962            0    0
# 424   Nvidia GeForce GTX 1070  Windows 10    4.42  149130            0    1
# 673    AMD Radeon R2 Graphics  Windows 10    2.20   18594            0    0
#
#      x_res y_res
# 310   1920  1080
# 485   1920  1080
# 871   1920  1080
# 697   1920  1080
# 161   1920  1080
# 1216  1600   900
# 648   1920  1080
# 96    1920  1080
# 424   2560  1440
# 673   1366   768

# %%
df['x_res'] = df['x_res'].astype('int')
df['y_res'] = df['y_res'].astype('int')
df['Touchscreen'] = df['Touchscreen'].astype('int')
df['Ips'] = df['Ips'].astype('int')

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1303 entries, 0 to 1302
# Data columns (total 15 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Company           1303 non-null   object
#  1   TypeName          1303 non-null   object
#  2   Inches            1303 non-null   float64
#  3   ScreenResolution  1303 non-null   object
#  4   Cpu               1303 non-null   object
#  5   Ram               1303 non-null   int32
#  6   Memory            1303 non-null   object
#  7   Gpu               1303 non-null   object
#  8   OpSys             1303 non-null   object
#  9   Weight            1303 non-null   float64
#  10  Price             1303 non-null   int32
#  11  Touchscreen       1303 non-null   int32
#  12  Ips               1303 non-null   int32
#  13  x_res             1303 non-null   int32
#  14  y_res             1303 non-null   int32
# dtypes: float64(2), int32(6), object(7)
# memory usage: 122.3+ KB

# %% [markdown]
# #### feature engineering -> 'Ppi' (pixel per inches) from 'x_res', 'y_res', 'Inches'

# %%
df['Ppi'] = (np.sqrt(df['x_res']**2 + df['y_res']**2) / df['Inches']).astype('float')

# %%
df.sample(5)
# Out:
#     Company            TypeName  Inches                  ScreenResolution  \
# 747      HP            Notebook    15.6                 Full HD 1920x1080
# 310  Lenovo            Notebook    13.3       IPS Panel Full HD 1920x1080
# 620      HP            Notebook    14.0                          1366x768
# 682    Dell              Gaming    15.6                 Full HD 1920x1080
# 900    Dell  2 in 1 Convertible    13.3  Quad HD+ / Touchscreen 3200x1800
#
#                              Cpu  Ram                Memory  \
# 747     Intel Core i3 6006U 2GHz    8             256GB SSD
# 310   Intel Core i5 7200U 2.5GHz    8             256GB SSD
# 620   Intel Core i5 7300U 2.6GHz    8             256GB SSD
# 682  Intel Core i5 7300HQ 2.5GHz   16  128GB SSD +  1TB HDD
# 900    Intel Core i7 7Y75 1.3GHz    8             512GB SSD
#
#                          Gpu       OpSys  Weight   Price  Touchscreen  Ips  \
# 747    Intel HD Graphics 520  Windows 10    1.86   28717            0    0
# 310    Intel HD Graphics 620  Windows 10    1.10   53226            0    1
# 620    Intel HD Graphics 620  Windows 10    2.31   59886            0    0
# 682  Nvidia GeForce GTX 1060  Windows 10    3.21  109277            0    0
# 900    Intel HD Graphics 615  Windows 10    1.24  107257            1    0
#
#      x_res  y_res         Ppi
# 747   1920   1080  141.211998
# 310   1920   1080  165.632118
# 620   1366    768  111.935204
# 682   1920   1080  141.211998
# 900   3200   1800  276.053530

# %%
df.drop(columns=['ScreenResolution'], inplace = True)
df.drop(columns=['Inches'], inplace = True)
df.drop(columns=['x_res'], inplace = True)
df.drop(columns=['y_res'], inplace = True)

# %%
df.sample(5)
# Out:
#      Company  TypeName                          Cpu  Ram        Memory  \
# 263     Dell  Notebook   Intel Core i5 7200U 2.5GHz    4       1TB HDD
# 1196  Lenovo  Notebook     Intel Core i3 6006U 2GHz    4       1TB HDD
# 1006      HP  Notebook   Intel Core i5 7200U 2.5GHz    4     256GB SSD
# 1010    Dell    Gaming  Intel Core i5 7300HQ 2.5GHz    8  1.0TB Hybrid
# 989     Dell  Notebook   Intel Core i5 7200U 2.5GHz    8     128GB SSD
#
#                           Gpu       OpSys  Weight  Price  Touchscreen  Ips  \
# 263     Intel HD Graphics 620  Windows 10    2.18  35004            0    0
# 1196       AMD Radeon R5 M430       No OS    1.90  19607            0    0
# 1006    Intel HD Graphics 620  Windows 10    1.95  64202            0    0
# 1010  Nvidia GeForce GTX 1050  Windows 10    2.65  50562            0    0
# 989    Intel HD Graphics 620   Windows 10    1.60  59620            0    0
#
#              Ppi
# 263   141.211998
# 1196  100.454670
# 1006  157.350512
# 1010  141.211998
# 989   157.350512

# %% [markdown]
# #### feature engineering -> 'Cpu name' from 'CPU'

# %%
df['Cpu'].value_counts()
# Out:
# Cpu
# Intel Core i5 7200U 2.5GHz       190
# Intel Core i7 7700HQ 2.8GHz      146
# Intel Core i7 7500U 2.7GHz       134
# Intel Core i7 8550U 1.8GHz        73
# Intel Core i5 8250U 1.6GHz        72
#                                 ...
# Intel Core M M3-6Y30 0.9GHz        1
# AMD A9-Series 9420 2.9GHz          1
# Intel Core i3 6006U 2.2GHz         1
# AMD A6-Series 7310 2GHz            1
# Intel Xeon E3-1535M v6 3.1GHz      1
# Name: count, Length: 118, dtype: int64

# %%
df['Cpu Name'] = df['Cpu'].apply(lambda x:" ".join(x.split()[0:3]))
df.sample(5)
# Out:
#         Company            TypeName                          Cpu  Ram  \
# 458   Microsoft           Ultrabook   Intel Core i7 7660U 2.5GHz    8
# 130        Dell            Notebook   Intel Core i5 7200U 2.5GHz    8
# 1222         HP            Notebook  AMD A12-Series 9720P 2.7GHz    6
# 570          HP         Workstation  Intel Core i5 7440HQ 2.8GHz    8
# 158        Dell  2 in 1 Convertible   Intel Core i7 8550U 1.8GHz    8
#
#          Memory                           Gpu         OpSys  Weight  Price  \
# 458   256GB SSD  Intel Iris Plus Graphics 640  Windows 10 S    1.25  95850
# 130     1TB HDD            AMD Radeon R7 M445    Windows 10    2.36  34045
# 1222    1TB HDD                AMD Radeon 530    Windows 10    2.10  28185
# 570   500GB HDD           Nvidia Quadro M1200    Windows 10    3.14  99153
# 158   256GB SSD        Intel UHD Graphics 620    Windows 10    1.56  55890
#
#       Touchscreen  Ips         Ppi              Cpu Name
# 458             1    0  200.842560         Intel Core i7
# 130             0    0  100.454670         Intel Core i5
# 1222            0    0  141.211998  AMD A12-Series 9720P
# 570             0    0  106.113062         Intel Core i5
# 158             1    0  141.211998         Intel Core i7

# %%
def fetch_processor(text):
    if text == 'Intel Core i7' or text == 'Intel Core i5' or text == 'Intel Core i3':
        return text
    else:
        if text.split()[0] == 'Intel':
            return 'Other Intel Processor'
        else:
            return 'AMD Processor'
        
        
df['Cpu brand'] = df['Cpu Name'].apply(fetch_processor) 

df.sample(5)
# Out:
#      Company            TypeName                                   Cpu  Ram  \
# 125       HP            Notebook  Intel Celeron Dual Core N3060 1.6GHz    4
# 470       HP  2 in 1 Convertible            Intel Core i7 8550U 1.8GHz    8
# 1033      HP            Notebook            Intel Core i5 6200U 2.3GHz    8
# 929       HP            Notebook            Intel Core i5 6200U 2.3GHz    4
# 830    Razer              Gaming           Intel Core i7 7820HK 2.9GHz   32
#
#          Memory                      Gpu       OpSys  Weight   Price  \
# 125   500GB HDD    Intel HD Graphics 400       No OS    1.86   13799
# 470   512GB SSD   Intel UHD Graphics 620  Windows 10    1.29  106506
# 1033  256GB SSD    Intel HD Graphics 520   Windows 7    1.95   63669
# 929   500GB HDD    Intel HD Graphics 520  Windows 10    1.95   61218
# 830   512GB SSD  Nvidia GeForce GTX 1080  Windows 10    3.49  292986
#
#       Touchscreen  Ips         Ppi            Cpu Name              Cpu brand
# 125             0    0  100.454670  Intel Celeron Dual  Other Intel Processor
# 470             1    1  331.264236       Intel Core i7          Intel Core i7
# 1033            0    0  157.350512       Intel Core i5          Intel Core i5
# 929             0    0  111.935204       Intel Core i5          Intel Core i5
# 830             1    0  254.671349       Intel Core i7          Intel Core i7

# %%
df['Cpu brand'].value_counts().plot(kind='bar', figsize=(5,5))
plt.show()

# %%
sns.barplot(x=df['Cpu brand'],y=df['Price'])
plt.xticks(rotation='vertical')
plt.show()

# %%
df.drop(columns=['Cpu','Cpu Name'],inplace=True)

df.sample(5)
# Out:
#      Company   TypeName  Ram                Memory  \
# 30     Chuwi   Notebook    4    64GB Flash Storage
# 425     Dell     Gaming    8  128GB SSD +  1TB HDD
# 542       HP  Ultrabook    8             256GB SSD
# 1178     MSI     Gaming   16  128GB SSD +  1TB HDD
# 262       HP   Notebook    4             500GB HDD
#
#                              Gpu       OpSys  Weight   Price  Touchscreen  \
# 30             Intel HD Graphics  Windows 10    1.89   13053            0
# 425   Nvidia GeForce GTX 1050 Ti  Windows 10    2.62   61751            0
# 542        Intel HD Graphics 620  Windows 10    1.34   61005            0
# 1178     Nvidia GeForce GTX 970M  Windows 10    1.91  114731            0
# 262        Intel HD Graphics 620  Windows 10    2.10   38468            0
#
#       Ips         Ppi              Cpu brand
# 30      0  141.211998  Other Intel Processor
# 425     1  141.211998          Intel Core i7
# 542     1  276.053530          Intel Core i7
# 1178    0  141.211998          Intel Core i7
# 262     1  141.211998          Intel Core i5

# %% [markdown]
# #### Memory

# %%
df['Memory'].value_counts()
# Out:
# Memory
# 256GB SSD                        412
# 1TB HDD                          223
# 500GB HDD                        132
# 512GB SSD                        118
# 128GB SSD +  1TB HDD              94
# 128GB SSD                         76
# 256GB SSD +  1TB HDD              73
# 32GB Flash Storage                38
# 2TB HDD                           16
# 64GB Flash Storage                15
# 512GB SSD +  1TB HDD              14
# 1TB SSD                           14
# 256GB SSD +  2TB HDD              10
# 1.0TB Hybrid                       9
# 256GB Flash Storage                8
# 16GB Flash Storage                 7
# 32GB SSD                           6
# 180GB SSD                          5
# 128GB Flash Storage                4
# 512GB SSD +  2TB HDD               3
# 16GB SSD                           3
# 512GB Flash Storage                2
# 1TB SSD +  1TB HDD                 2
# 256GB SSD +  500GB HDD             2
# 128GB SSD +  2TB HDD               2
# 256GB SSD +  256GB SSD             2
# 512GB SSD +  256GB SSD             1
# 512GB SSD +  512GB SSD             1
# 64GB Flash Storage +  1TB HDD      1
# 1TB HDD +  1TB HDD                 1
# 32GB HDD                           1
# 64GB SSD                           1
# 128GB HDD                          1
# 240GB SSD                          1
# 8GB SSD                            1
# 508GB Hybrid                       1
# 1.0TB HDD                          1
# 512GB SSD +  1.0TB Hybrid          1
# 256GB SSD +  1.0TB Hybrid          1
# Name: count, dtype: int64

# %%
# Convert column to string and clean up text
df['Memory'] = df['Memory'].astype(str).replace(r'\.0', '', regex=True)
df["Memory"] = df["Memory"].str.replace('GB', '')
df["Memory"] = df["Memory"].str.replace('TB', '000')

# Split into first and second storage layers
new = df["Memory"].str.split("+", n=1, expand=True)

df["first"] = new[0].str.strip()
df["second"] = new[1]

# Identify storage types for first layer
df["Layer1HDD"] = df["first"].apply(lambda x: 1 if "HDD" in x else 0)
df["Layer1SSD"] = df["first"].apply(lambda x: 1 if "SSD" in x else 0)
df["Layer1Hybrid"] = df["first"].apply(lambda x: 1 if "Hybrid" in x else 0)
df["Layer1Flash_Storage"] = df["first"].apply(lambda x: 1 if "Flash Storage" in x else 0)

# Identify storage types for second layer BEFORE converting to int
df["Layer2HDD"] = df["second"].apply(lambda x: 1 if pd.notna(x) and "HDD" in x else 0)
df["Layer2SSD"] = df["second"].apply(lambda x: 1 if pd.notna(x) and "SSD" in x else 0)
df["Layer2Hybrid"] = df["second"].apply(lambda x: 1 if pd.notna(x) and "Hybrid" in x else 0)
df["Layer2Flash_Storage"] = df["second"].apply(lambda x: 1 if pd.notna(x) and "Flash Storage" in x else 0)

# **Extract only numeric values safely**
df["first"] = df["first"].str.extract(r'(\d+)')  # Extract digits only
df["second"] = df["second"].str.extract(r'(\d+)')

# Handle NaN values before conversion
df["first"] = df["first"].fillna(0).astype(int)
df["second"] = df["second"].fillna(0).astype(int)

# Compute final storage capacity
df["HDD"] = (df["first"] * df["Layer1HDD"]) + (df["second"] * df["Layer2HDD"])
df["SSD"] = (df["first"] * df["Layer1SSD"]) + (df["second"] * df["Layer2SSD"])
df["Hybrid"] = (df["first"] * df["Layer1Hybrid"]) + (df["second"] * df["Layer2Hybrid"])
df["Flash_Storage"] = (df["first"] * df["Layer1Flash_Storage"]) + (df["second"] * df["Layer2Flash_Storage"])

# Drop unnecessary columns
df.drop(columns=['first', 'second', 'Layer1HDD', 'Layer1SSD', 'Layer1Hybrid',
                 'Layer1Flash_Storage', 'Layer2HDD', 'Layer2SSD', 'Layer2Hybrid',
                 'Layer2Flash_Storage'], inplace=True)

# %%
df.sample(10)
# Out:
#      Company   TypeName  Ram               Memory  \
# 191     Vero   Notebook    4     32 Flash Storage
# 1043  Lenovo   Notebook    8              256 SSD
# 1066    Asus     Gaming   64             1000 SSD
# 254     Acer   Notebook    4              256 SSD
# 282   Lenovo     Gaming    8              256 SSD
# 195       HP   Notebook    8             1000 HDD
# 180     Dell   Notebook   16  256 SSD +  2000 HDD
# 1124    Asus   Notebook    4             1000 HDD
# 249    Apple  Ultrabook    8              512 SSD
# 355     Dell   Notebook    8  128 SSD +  2000 HDD
#
#                                Gpu       OpSys  Weight   Price  Touchscreen  \
# 191          Intel HD Graphics 500  Windows 10    1.30   13852            0
# 1043         Intel HD Graphics 520  Windows 10    2.30   55922            0
# 1066       Nvidia GeForce GTX 980   Windows 10    3.58  211788            0
# 254           Nvidia GeForce MX130  Windows 10    3.00   37402            0
# 282        Nvidia GeForce GTX 1050  Windows 10    2.50   44169            0
# 195           Nvidia GeForce 930MX  Windows 10    2.50   48697            0
# 180                 AMD Radeon 530       Linux    2.02   55890            0
# 1124         Intel HD Graphics 620  Windows 10    2.00   23176            0
# 249   Intel Iris Plus Graphics 650       macOS    1.37  108691            0
# 355                 AMD Radeon 530  Windows 10    2.02   51729            0
#
#       Ips         Ppi              Cpu brand   HDD   SSD  Hybrid  \
# 191     1  157.350512  Other Intel Processor     0     0       0
# 1043    0  141.211998          Intel Core i5     0   256       0
# 1066    1  127.335675          Intel Core i7     0  1000       0
# 254     1  127.335675          Intel Core i3     0   256       0
# 282     1  141.211998          Intel Core i5     0   256       0
# 195     1  127.335675          Intel Core i5  1000     0       0
# 180     0  141.211998          Intel Core i7  2000   256       0
# 1124    0  100.454670          Intel Core i3  1000     0       0
# 249     1  226.983005          Intel Core i5     0   512       0
# 355     0  141.211998          Intel Core i7  2000   128       0
#
#       Flash_Storage
# 191              32
# 1043              0
# 1066              0
# 254               0
# 282               0
# 195               0
# 180               0
# 1124              0
# 249               0
# 355               0

# %%
hybrid_laptops = df[df["Hybrid"] != 0]
hybrid_laptops
# Out:
#      Company  TypeName  Ram                  Memory                      Gpu  \
# 151     Dell    Gaming    8             1000 Hybrid  Nvidia GeForce GTX 1050
# 976   Lenovo  Notebook    4              508 Hybrid    Intel HD Graphics 520
# 1010    Dell    Gaming    8             1000 Hybrid  Nvidia GeForce GTX 1050
# 1081  Lenovo    Gaming   32  512 SSD +  1000 Hybrid  Nvidia GeForce GTX 980M
# 1116  Lenovo    Gaming   16  256 SSD +  1000 Hybrid  Nvidia GeForce GTX 980M
# 1135  Lenovo  Notebook   16             1000 Hybrid       AMD Radeon R7 M360
# 1158  Lenovo  Notebook    8             1000 Hybrid       AMD Radeon R5 M330
# 1176  Lenovo  Notebook    4             1000 Hybrid    Intel HD Graphics 520
# 1258  Lenovo  Notebook    8             1000 Hybrid       AMD Radeon R5 M330
# 1266      HP  Notebook    6             1000 Hybrid       AMD Radeon R7 M440
# 1280      HP  Notebook    6             1000 Hybrid       AMD Radeon R7 M440
# 1294      HP  Notebook    6             1000 Hybrid       AMD Radeon R7 M440
#
#            OpSys  Weight   Price  Touchscreen  Ips         Ppi      Cpu brand  \
# 151   Windows 10    2.62   47898            0    0  141.211998  Intel Core i7
# 976    Windows 7    1.70   53386            0    0  111.935204  Intel Core i5
# 1010  Windows 10    2.65   50562            0    0  141.211998  Intel Core i5
# 1081  Windows 10    4.60  172627            0    1  127.335675  Intel Core i7
# 1116  Windows 10    4.60  146519            0    1  127.335675  Intel Core i7
# 1135  Windows 10    2.50   58554            0    0  141.211998  Intel Core i7
# 1158  Windows 10    2.50   42010            0    0  141.211998  Intel Core i5
# 1176   Windows 7    2.32   43956            0    0  141.211998  Intel Core i7
# 1258   Windows 7    2.32   47685            0    0  141.211998  Intel Core i7
# 1266  Windows 10    2.04   29303            0    0  141.211998  AMD Processor
# 1280  Windows 10    2.04   29303            0    0  141.211998  AMD Processor
# 1294  Windows 10    2.04   29303            0    0  141.211998  AMD Processor
#
#       HDD  SSD  Hybrid  Flash_Storage
# 151     0    0    1000              0
# 976     0    0     508              0
# 1010    0    0    1000              0
# 1081    0  512    1000              0
# 1116    0  256    1000              0
# 1135    0    0    1000              0
# 1158    0    0    1000              0
# 1176    0    0    1000              0
# 1258    0    0    1000              0
# 1266    0    0    1000              0
# 1280    0    0    1000              0
# 1294    0    0    1000              0

# %%
flash_laptops = df[df["Flash_Storage"] != 0]
flash_laptops
# Out:
#      Company   TypeName  Ram             Memory                      Gpu  \
# 1      Apple  Ultrabook    8  128 Flash Storage   Intel HD Graphics 6000
# 6      Apple  Ultrabook   16  256 Flash Storage  Intel Iris Pro Graphics
# 7      Apple  Ultrabook    8  256 Flash Storage   Intel HD Graphics 6000
# 20      Asus    Netbook    2   32 Flash Storage    Intel HD Graphics 400
# 26     Apple  Ultrabook    8  128 Flash Storage   Intel HD Graphics 6000
# ...      ...        ...  ...                ...                      ...
# 1272  Lenovo   Notebook    2   64 Flash Storage        Intel HD Graphics
# 1282      HP    Netbook    2   32 Flash Storage    Intel HD Graphics 400
# 1286  Lenovo   Notebook    2   64 Flash Storage        Intel HD Graphics
# 1296      HP    Netbook    2   32 Flash Storage    Intel HD Graphics 400
# 1300  Lenovo   Notebook    2   64 Flash Storage        Intel HD Graphics
#
#            OpSys  Weight   Price  Touchscreen  Ips         Ppi  \
# 1          macOS    1.34   47895            0    0  127.677940
# 6       Mac OS X    2.04  114017            0    1  220.534624
# 7          macOS    1.34   61735            0    0  127.677940
# 20    Windows 10    0.98   10224            0    0  135.094211
# 26      Mac OS X    1.35   58554            0    0  127.677940
# ...          ...     ...     ...          ...  ...         ...
# 1272  Windows 10    1.50   12201            0    0  111.935204
# 1282  Windows 10    1.17   11135            0    0  135.094211
# 1286  Windows 10    1.50   12201            0    0  111.935204
# 1296  Windows 10    1.17   11135            0    0  135.094211
# 1300  Windows 10    1.50   12201            0    0  111.935204
#
#                   Cpu brand  HDD  SSD  Hybrid  Flash_Storage
# 1             Intel Core i5    0    0       0            128
# 6             Intel Core i7    0    0       0            256
# 7             Intel Core i5    0    0       0            256
# 20    Other Intel Processor    0    0       0             32
# 26            Intel Core i5    0    0       0            128
# ...                     ...  ...  ...     ...            ...
# 1272  Other Intel Processor    0    0       0             64
# 1282  Other Intel Processor    0    0       0             32
# 1286  Other Intel Processor    0    0       0             64
# 1296  Other Intel Processor    0    0       0             32
# 1300  Other Intel Processor    0    0       0             64
#
# [75 rows x 16 columns]

# %%
df.drop(columns=['Memory'],inplace=True)

# %%
newdf = df.apply(pd.to_numeric, errors='coerce')  # Convert all columns to numeric, setting errors as NaN
print(newdf.corr()["Price"])
# Out:
# Company               NaN
# TypeName              NaN
# Ram              0.743007
# Gpu                   NaN
# OpSys                 NaN
# Weight           0.210370
# Price            1.000000
# Touchscreen      0.191226
# Ips              0.252207
# Ppi              0.473487
# Cpu brand             NaN
# HDD             -0.096442
# SSD              0.670799
# Hybrid           0.007989
# Flash_Storage   -0.040511
# Name: Price, dtype: float64

# %%
df.drop(columns=['Hybrid','Flash_Storage'],inplace=True)

df.sample(5)
# Out:
#      Company  TypeName  Ram                      Gpu       OpSys  Weight  \
# 1212     MSI    Gaming   16  Nvidia GeForce GTX 1060  Windows 10    2.43
# 303   Lenovo  Notebook    8     Nvidia GeForce 940MX       No OS    2.20
# 940       HP    Gaming    8  Nvidia GeForce GTX 965M  Windows 10    2.75
# 759     Acer  Notebook    4    Intel HD Graphics 620  Windows 10    2.10
# 54      Acer  Notebook    4    Intel HD Graphics 620  Windows 10    2.40
#
#        Price  Touchscreen  Ips         Ppi      Cpu brand   HDD  SSD
# 1212  103842            0    1  127.335675  Intel Core i7  1000  256
# 303    29250            0    0  100.454670  Intel Core i5  2000    0
# 940    74538            0    1  127.335675  Intel Core i5  1000  128
# 759    31914            0    0  100.454670  Intel Core i5     0  256
# 54     20459            0    0  100.454670  Intel Core i3  1000    0

# %% [markdown]
# #### Gpu

# %%
df['Gpu'].value_counts()
# Out:
# Gpu
# Intel HD Graphics 620      281
# Intel HD Graphics 520      185
# Intel UHD Graphics 620      68
# Nvidia GeForce GTX 1050     66
# Nvidia GeForce GTX 1060     48
#                           ...
# AMD Radeon R5 520            1
# AMD Radeon R7                1
# Intel HD Graphics 540        1
# AMD Radeon 540               1
# ARM Mali T860 MP4            1
# Name: count, Length: 110, dtype: int64

# %%
df['Gpu brand'] = df['Gpu'].apply(lambda x:x.split()[0])

# %%
df['Gpu brand'].value_counts()
# Out:
# Gpu brand
# Intel     722
# Nvidia    400
# AMD       180
# ARM         1
# Name: count, dtype: int64

# %%
df = df[df['Gpu brand'] != 'ARM']

# %%
df['Gpu brand'].value_counts()
# Out:
# Gpu brand
# Intel     722
# Nvidia    400
# AMD       180
# Name: count, dtype: int64

# %%
sns.barplot(x=df['Gpu brand'],y=df['Price'],estimator=np.median)
plt.xticks(rotation='vertical')
plt.show()

# %%
df.drop(columns=['Gpu'],inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[726], line 1
# ----> 1 df.drop(columns=['Gpu'],inplace=True)
#       3 df.sample(5)
#
# File c:\Users\saikat roy\anaconda3\Lib\site-packages\pandas\core\frame.py:5581, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5433 def drop(
#    5434     self,
#    5435     labels: IndexLabel | None = None,
#    (...)
#    5442     errors: IgnoreRaise = "raise",
#    5443 ) -> DataFrame | None:
#    5444     """
#    5445     Drop specified labels from rows or columns.
#    5446
#    (...)
#    5579             weight  1.0     0.8
#    5580     """
# -> 5581     return super().drop(
#    5582         labels=labels,
#    5583         axis=axis,
#    5584         index=index,
#    5585         columns=columns,
#    5586         level=level,
#    5587         inplace=inplace,
#    5588         errors=errors,
#    5589     )
#
# File c:\Users\saikat roy\anaconda3\Lib\site-packages\pandas\core\generic.py:4788, in NDFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    4786 for axis, labels in axes.items():
#    4787     if labels is not None:
# -> 4788         obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4790 if inplace:
#    4791     self._update_inplace(obj)
#
# File c:\Users\saikat roy\anaconda3\Lib\site-packages\pandas\core\generic.py:4830, in NDFrame._drop_axis(self, labels, axis, level, errors, only_slice)
#    4828         new_axis = axis.drop(labels, level=level, errors=errors)
#    4829     else:
# -> 4830         new_axis = axis.drop(labels, errors=errors)
#    4831     indexer = axis.get_indexer(new_axis)
#    4833 # Case for non-unique axis
#    4834 else:
#
# File c:\Users\saikat roy\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:7070, in Index.drop(self, labels, errors)
#    7068 if mask.any():
#    7069     if errors != "ignore":
# -> 7070         raise KeyError(f"{labels[mask].tolist()} not found in axis")
#    7071     indexer = indexer[~mask]
#    7072 return self.delete(indexer)
#
# KeyError: "['Gpu'] not found in axis"

# %%
df
# Out:
#      Company            TypeName  Ram       OpSys  Weight   Price  \
# 0      Apple           Ultrabook    8       macOS    1.37   71378
# 1      Apple           Ultrabook    8       macOS    1.34   47895
# 2         HP            Notebook    8       No OS    1.86   30636
# 3      Apple           Ultrabook   16       macOS    1.83  135195
# 4      Apple           Ultrabook    8       macOS    1.37   96095
# ...      ...                 ...  ...         ...     ...     ...
# 1298  Lenovo  2 in 1 Convertible    4  Windows 10    1.80   33992
# 1299  Lenovo  2 in 1 Convertible   16  Windows 10    1.30   79866
# 1300  Lenovo            Notebook    2  Windows 10    1.50   12201
# 1301      HP            Notebook    6  Windows 10    2.19   40705
# 1302    Asus            Notebook    4  Windows 10    2.20   19660
#
#       Touchscreen  Ips         Ppi              Cpu brand   HDD  SSD Gpu brand
# 0               0    1  226.983005          Intel Core i5     0  128     Intel
# 1               0    0  127.677940          Intel Core i5     0    0     Intel
# 2               0    0  141.211998          Intel Core i5     0  256     Intel
# 3               0    1  220.534624          Intel Core i7     0  512       AMD
# 4               0    1  226.983005          Intel Core i5     0  256     Intel
# ...           ...  ...         ...                    ...   ...  ...       ...
# 1298            1    1  157.350512          Intel Core i7     0  128     Intel
# 1299            1    1  276.053530          Intel Core i7     0  512     Intel
# 1300            0    0  111.935204  Other Intel Processor     0    0     Intel
# 1301            0    0  100.454670          Intel Core i7  1000    0       AMD
# 1302            0    0  100.454670  Other Intel Processor   500    0     Intel
#
# [1302 rows x 13 columns]

# %% [markdown]
# #### OPSys

# %%
df['OpSys'].value_counts()
# Out:
# OpSys
# Windows 10      1072
# No OS             66
# Linux             62
# Windows 7         45
# Chrome OS         26
# macOS             13
# Mac OS X           8
# Windows 10 S       8
# Android            2
# Name: count, dtype: int64

# %%
sns.barplot(x=df['OpSys'],y=df['Price'], width= 0.5)
plt.xticks(rotation='vertical')
plt.show()

# %%
def cat_os(inp):
    if inp == 'Windows 10' or inp == 'Windows 7' or inp == 'Windows 10 S':
        return 'Windows'
    elif inp == 'macOS' or inp == 'Mac OS X':
        return 'Mac'
    else:
        return 'Others/No OS/Linux'
    
    
df['Os'] = df['OpSys'].apply(cat_os)

df.sample(5)
# Out:
# C:\Users\saikat roy\AppData\Local\Temp\ipykernel_24272\2009483269.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Os'] = df['OpSys'].apply(cat_os)
#     Company            TypeName  Ram       OpSys  Weight   Price  Touchscreen  \
# 428      HP              Gaming   12  Windows 10    3.35  106506            0
# 733    Acer            Notebook    4  Windows 10    2.40   29783            0
# 335      HP            Notebook    8  Windows 10    1.48   67559            0
# 684  Lenovo  2 in 1 Convertible    8  Windows 10    1.19   79866            1
# 266    Asus  2 in 1 Convertible    8  Windows 10    1.10   79866            1
#
#      Ips         Ppi      Cpu brand   HDD   SSD Gpu brand       Os
# 428    0  127.335675  Intel Core i7  1000   256    Nvidia  Windows
# 733    0  100.454670  Intel Core i5   500     0     Intel  Windows
# 335    0  157.350512  Intel Core i5     0   256     Intel  Windows
# 684    1  165.632118  Intel Core i7     0   512     Intel  Windows
# 266    0  165.632118  Intel Core i7     0  1024     Intel  Windows

# %%
df.drop(columns=['OpSys'],inplace=True)
# Out:
# C:\Users\saikat roy\AppData\Local\Temp\ipykernel_24272\3105339334.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.drop(columns=['OpSys'],inplace=True)

# %%
sns.barplot(x=df['Os'],y=df['Price'])
plt.xticks(rotation='vertical')
plt.show()

# %%
sns.distplot(df['Weight'])
# Out:
# C:\Users\saikat roy\AppData\Local\Temp\ipykernel_24272\3442460328.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['Weight'])
# <Axes: xlabel='Weight', ylabel='Density'>

# %%
df
# Out:
#      Company            TypeName  Ram  Weight   Price  Touchscreen  Ips  \
# 0      Apple           Ultrabook    8    1.37   71378            0    1
# 1      Apple           Ultrabook    8    1.34   47895            0    0
# 2         HP            Notebook    8    1.86   30636            0    0
# 3      Apple           Ultrabook   16    1.83  135195            0    1
# 4      Apple           Ultrabook    8    1.37   96095            0    1
# ...      ...                 ...  ...     ...     ...          ...  ...
# 1298  Lenovo  2 in 1 Convertible    4    1.80   33992            1    1
# 1299  Lenovo  2 in 1 Convertible   16    1.30   79866            1    1
# 1300  Lenovo            Notebook    2    1.50   12201            0    0
# 1301      HP            Notebook    6    2.19   40705            0    0
# 1302    Asus            Notebook    4    2.20   19660            0    0
#
#              Ppi              Cpu brand   HDD  SSD Gpu brand  \
# 0     226.983005          Intel Core i5     0  128     Intel
# 1     127.677940          Intel Core i5     0    0     Intel
# 2     141.211998          Intel Core i5     0  256     Intel
# 3     220.534624          Intel Core i7     0  512       AMD
# 4     226.983005          Intel Core i5     0  256     Intel
# ...          ...                    ...   ...  ...       ...
# 1298  157.350512          Intel Core i7     0  128     Intel
# 1299  276.053530          Intel Core i7     0  512     Intel
# 1300  111.935204  Other Intel Processor     0    0     Intel
# 1301  100.454670          Intel Core i7  1000    0       AMD
# 1302  100.454670  Other Intel Processor   500    0     Intel
#
#                       Os
# 0                    Mac
# 1                    Mac
# 2     Others/No OS/Linux
# 3                    Mac
# 4                    Mac
# ...                  ...
# 1298             Windows
# 1299             Windows
# 1300             Windows
# 1301             Windows
# 1302             Windows
#
# [1302 rows x 13 columns]

# %%
df.to_csv("data/Final_Dataset.csv", index=False)
